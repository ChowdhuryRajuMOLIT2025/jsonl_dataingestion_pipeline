# %%
print("Hello")
# Out:
# Hello

# %%
import warnings
warnings.filterwarnings("ignore")

import numpy as np
import pandas as pd
pd.set_option("display.max_columns", None)
pd.set_option("display.max_rows", 100)
pd.set_option("display.max_colwidth", None)
pd.set_option("display.width", None)

# %%
curr_file_name = "./output_jsonl/shipment_2026-01_1.jsonl"

# %%
prev_file_name = "shipment_dec25.jsonl"

# %%
curr_df = pd.read_json(curr_file_name, lines=True)

# %%
prev_df = pd.read_json(prev_file_name, lines=True)

# %%
curr_df.head(3)
# Out:
#     document_id  \
# 0  320001130322
# 1  320001131990
# 2  320001132482
#
# ...

# %%
prev_df.head(1)
# Out:
#     document_id  \
# 0  320001124314
#
# ...

# %%
prev_df.columns
# Out:
# Index(['document_id', 'content', 'metadata', 'consignee_code'], dtype='object')

# %%
curr_df.iloc[493]['metadata']
# Out:
# {'job_no': 'VN2ASK0613',
#  'carr_eqp_uid': '320001130674',
#  'container_number': 'FFAU4961098',
#  'container_type': 'C4',
#  'destination_service': 'CY',
#  'consignee_raw': 'AMER SPORTS KOREA LTD(0005180)',
#  'po_numbers': ['5302971364',
#   '5302971901',
#   '5302972862',
#   '5302972863',
#   '5302972864',
#   '5302972865',
#   '5302972866',
#   '5302972867',
#   '5302972868',
#   '5302972869',
#   '5302972870',
#   '5302972871',
#   '5302972872',
#   '5302972873',
#   '5302972874',
#   '5302972875',
#   '5302972876',
#   '5302972877',
#   '5302985866',
#   '5302985867',
#   '5302985869',
#   '5302985872',
#   '5302985873',
#   '5302985875',
#   '5302985876',
#   '5302985878',
#   '5302985879',
#   '5302985881',
#   '5302987944',
#   '5302987945',
#   '5302987946',
#   '5302987948',
#   '5302988411'],
#  'booking_numbers': ['VN2091746', 'VN2092050', 'VN2092343', 'VN2092417'],
#  'fcr_numbers': ['VN2091746', 'VN2092050', 'VN2092343', 'VN2092417'],
# ...

# %%
print(curr_df.iloc[493]['content'])
# Out:
# job_no: VN2ASK0613
# job_type: OCB
# transport_mode: SEA
# true_carrier_scac_name: PAN CONTINENTAL SHIPPING CO LTD
# carr_eqp_uid: 320001130674
# container_number: FFAU4961098
# container_type: C4
# seal_number: 867180
# hot_container_flag: False
# destination_service: CY
# consignee_name: AMER SPORTS KOREA LTD
# po_numbers: 5302971364, 5302971901, 5302972862, 5302972863, 5302972864, 5302972865, 5302972866, 5302972867, 5302972868, 5302972869, 5302972870, 5302972871, 5302972872, 5302972873, 5302972874, 5302972875, 5302972876, 5302972877, 5302985866, 5302985867, 5302985869, 5302985872, 5302985873, 5302985875, 5302985876, 5302985878, 5302985879, 5302985881, 5302987944, 5302987945, 5302987946, 5302987948, 5302988411
# booking_numbers: VN2091746, VN2092050, VN2092343, VN2092417
# cargo_ready_date: N/A
# cargo_receiveds_date: 2025-11-26,2025-11-26,2025-11-28,2025-12-02
# ...

# %%
print(prev_df.iloc[493]['content'])
# Out:
# Container: FFAU4961098 | Consignee: AMER SPORTS KOREA LTD | Current shipment status: AT_DISCHARGE_PORT
#
# Parties & service: Consignee: AMER SPORTS KOREA LTD | Supplier/Vendor: CIBAO CO., LTD(0046288), LMG VINA CO., LTD(0048104), POUYUEN VIETNAM COMPANY LIMITED.,(0010100), SUNGJIN INC VINA CO., LTD(0030951) | Manufacturer: CIBAO CO., LTD(0046288), LMG VINA CO., LTD(0048104), POUYUEN VIETNAM COMPANY LIMITED.,(0010100), SUNGJIN INC VINA CO., LTD(0030951) | Job type: OCB | Destination service: CY | Transport mode: SEA | Hot container flag: False | Booking approval status: (VN2091746, VN2092050, VN2092343, VN2092417)
#
# Routing & movements: Origin: HO CHI MINH(VNSGN) | Load Port: HO CHI MINH(VNSGN) | Discharge Port: BUSAN(KRPUS) | Place of Delivery: BUSAN(KRPUS) | Final Destination: BUSAN(KRPUS) || Route summary: Origin: HO CHI MINH(VNSGN) -> Discharge Port: BUSAN(KRPUS) || Vessel summary: First vessel: KMTC BANGKOK || Carrier summary: Operated by PAN CONTINENTAL SHIPPING CO LTD
#
# ...
